# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the data into pandas dataframes
members = pd.read_csv('./Filtered_Dataset/members_filtered.csv')
transactions = pd.read_csv('./Filtered_Dataset/transactions_filtered.csv')
user_logs = pd.read_csv('./Filtered_Dataset/user_logs_filtered.csv')
labels = pd.read_csv('./Filtered_Dataset/labels_filtered.csv')
features_all = pd.read_csv('./features_all.csv')

# %%
# Getting the date in YMD format

def pd_to_date(df_col):
    df_col = pd.to_datetime(df_col, format = '%Y%m%d')
    return df_col

# %%
# Getting the timestamps in a consistent format

user_logs['date'] = pd_to_date(user_logs['date'])
transactions['transaction_date'] = pd_to_date(transactions['transaction_date'])
transactions['membership_expire_date'] = pd_to_date(transactions['membership_expire_date'])
members['registration_init_time'] = pd_to_date(members['registration_init_time'])

# %%
# Getting more info on data

print('Members: \n')
members.info()
print()
print('Labels: \n')
labels.info()
print()
print('Transactions: \n')
transactions.info()
print()
print('User Logs: \n')
user_logs.info()
print()
print('All Features: \n')
features_all.info()
# Out:
# Members:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17375 entries, 0 to 17374
# Data columns (total 6 columns):
# msno                      17375 non-null object
# city                      17375 non-null int64
# bd                        17375 non-null int64
# gender                    7772 non-null object
# registerd_via             17375 non-null int64
# registration_init_time    17375 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 814.5+ KB
#
# Labels:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17375 entries, 0 to 17374
# Data columns (total 2 columns):
# msno        17375 non-null object
# is_churn    17375 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 271.6+ KB
#
# Transactions:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282160 entries, 0 to 282159
# Data columns (total 9 columns):
# msno                      282160 non-null object
# payment_method_id         282160 non-null int64
# payment_plan_days         282160 non-null int64
# plan_list_price           282160 non-null int64
# actual_amount_paid        282160 non-null int64
# is_auto_renew             282160 non-null int64
# transaction_date          282160 non-null datetime64[ns]
# membership_expire_date    282160 non-null datetime64[ns]
# is_cancel                 282160 non-null int64
# dtypes: datetime64[ns](2), int64(6), object(1)
# memory usage: 19.4+ MB
#
# User Logs:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4883573 entries, 0 to 4883572
# Data columns (total 9 columns):
# msno          object
# date          datetime64[ns]
# num_25        int64
# num_50        int64
# num_75        int64
# num_985       int64
# num_100       int64
# num_unq       int64
# total_secs    float64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(1)
# memory usage: 335.3+ MB
#
# All Features:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17375 entries, 0 to 17374
# Columns: 115 entries, msno to ('within_days_999', 'num_100', 'mean')
# dtypes: float64(56), int64(54), object(5)
# memory usage: 15.2+ MB

# %%
user_logs.head()

# %%
members.head()

# %%
transactions.head()

# %%
transactions.tail()

# %%
features_all.head()

# %%
transactions.describe()

# %%
# Grouping by the member (msno)
transactions_gb = transactions.sort_values(["transaction_date"]).groupby(['msno'])

# How many groups i.e. members i.e. msno's. We're good if this is the same number as the members table
print('%d Groups/msnos' %(len(transactions_gb.groups)))
# Out:
# 17375 Groups/msnos

# %%
transactions_gb.head()

# %% [markdown]
# Features:
#     Plan no of days for the latest transaction
#     Plan actual amount paid/day for the latest transaction
#     plan total amount paid for the latest transaction
#     Is_auto_renew for the latest transaction
#     is_cancel for the latest transaction
#     Total number of plan days
#     Total of all the amounts paid for the plan
#     Plan day difference among the latest and previous transaction
#     Amount paid/day difference among the latest and previous transaction
#     ....

# %%
# Features: Total_plan_days, Total_amount_paid
transactions_features = (transactions_gb
    .agg({'payment_plan_days':'sum', 'actual_amount_paid':'sum' })
    .rename(columns={'payment_plan_days': 'Total_plan_days', 'actual_amount_paid': 'Total_amount_paid',})
                      )
transactions_features.head()
# Out:
#                                               Total_plan_days  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=              720
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=              240
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=              780
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=              210
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=              180
#
#                                               Total_amount_paid
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=               3725
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=               1192
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=               3354
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=               1043
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=                894

# %%
# Features: latest transaction
latest_transaction_gb = transactions_gb.tail([1])
latest_transaction_gb.set_index('msno', inplace = True)
latest_transaction_gb.head()
# Out:
#                                               payment_method_id  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                 38
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 41
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                 32
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                 22
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                 32
#
#                                               payment_plan_days  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                450
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 30
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                410
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                395
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                395
#
#                                               plan_list_price  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=             1788
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=              149
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=             1788
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=             1599
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=             1599
#
#                                               actual_amount_paid  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                1788
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 149
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                1788
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                1599
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                1599
#
#                                               is_auto_renew transaction_date  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=              0       2015-06-30
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=              1       2015-09-19
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=              0       2015-09-23
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=              0       2015-10-13
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=              0       2015-11-12
#
#                                              membership_expire_date  is_cancel
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=             2017-02-18          0
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=             2017-03-20          0
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=             2017-02-03          0
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=             2017-02-09          0
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=             2017-02-13          0

# %%
latest_transaction_gb.tail()

# %%
# Plan actual amount paid/day for the latest transaction
# Adding the collumn amount_paid_per_day
latest_transaction_gb['amount_paid_per_day'] = (latest_transaction_gb['actual_amount_paid']/latest_transaction_gb['payment_plan_days'])
latest_transaction_gb.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                               payment_method_id  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                 38
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 41
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                 32
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                 22
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                 32
#
#                                               payment_plan_days  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                450
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 30
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                410
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                395
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                395
#
#                                               plan_list_price  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=             1788
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=              149
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=             1788
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=             1599
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=             1599
#
#                                               actual_amount_paid  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                1788
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 149
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                1788
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                1599
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                1599
#
#                                               is_auto_renew transaction_date  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=              0       2015-06-30
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=              1       2015-09-19
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=              0       2015-09-23
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=              0       2015-10-13
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=              0       2015-11-12
#
#                                              membership_expire_date  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=             2017-02-18
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=             2017-03-20
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=             2017-02-03
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=             2017-02-09
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=             2017-02-13
#
#                                               is_cancel  amount_paid_per_day
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=          0             3.973333
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=          0             4.966667
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=          0             4.360976
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=          0             4.048101
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=          0             4.048101

# %%
# TODO Differences among latest and previous transaction

# %%
# TODO: DOES NOT WORK YET: Add to the features table
latest_transaction_gb.head()
# transactions_features = transactions_features.join(latest_transaction_gb, how = 'inner')
# transactions_features.head()
# Out:
#                                               payment_method_id  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                 38
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 41
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                 32
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                 22
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                 32
#
#                                               payment_plan_days  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                450
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 30
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                410
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                395
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                395
#
#                                               plan_list_price  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=             1788
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=              149
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=             1788
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=             1599
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=             1599
#
#                                               actual_amount_paid  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=                1788
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=                 149
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=                1788
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=                1599
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=                1599
#
#                                               is_auto_renew transaction_date  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=              0       2015-06-30
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=              1       2015-09-19
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=              0       2015-09-23
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=              0       2015-10-13
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=              0       2015-11-12
#
#                                              membership_expire_date  \
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=             2017-02-18
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=             2017-03-20
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=             2017-02-03
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=             2017-02-09
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=             2017-02-13
#
#                                               is_cancel  amount_paid_per_day
# msno
# NRzJYmVfPD9TfCGGP9ai1fHAr69INjKXREgt6ViaYwA=          0             3.973333
# GVfMVTbKtQgHkmTaJZq0PSM/49neJxN2CdM/j6SGGNs=          0             4.966667
# NSHsvkXPX2yjnIzWXW373xGMssTh1u26rqRVzHadXR0=          0             4.360976
# H3036d7cObAUujRSPEq7xEHJboHgQJ58Kv0zWfJKh0E=          0             4.048101
# tT2aF3w8Ox+2bC2GaEU/jp8dVvhhAO5inykLclBtXy8=          0             4.048101

# %%
transactions_features.head()
# Out:
#                                               Total_plan_days  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=              720
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=              240
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=              780
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=              210
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=              180
#
#                                               Total_amount_paid
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=               3725
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=               1192
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=               3354
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=               1043
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=                894

# %%
transactions_features = transactions_features.join(latest_transaction_gb, how = 'inner')
transactions_features.head()
# Out:
#                                               Total_plan_days  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=              720
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=              240
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=              780
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=              210
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=              180
#
#                                               Total_amount_paid  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=               3725
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=               1192
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=               3354
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=               1043
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=                894
#
#                                               payment_method_id  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=                 38
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=                 41
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=                 41
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=                 39
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=                 41
#
#                                               payment_plan_days  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=                 30
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=                 30
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=                 30
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=                 30
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=                 30
#
#                                               plan_list_price  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=              149
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=              149
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=              129
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=              149
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=              149
#
#                                               actual_amount_paid  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=                 149
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=                 149
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=                 129
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=                 149
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=                 149
#
#                                               is_auto_renew transaction_date  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=              0       2017-02-16
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=              1       2017-01-06
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=              1       2017-02-14
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=              1       2017-01-31
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=              1       2017-01-23
#
#                                              membership_expire_date  \
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=             2017-03-18
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=             2017-01-07
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=             2017-03-15
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=             2017-03-11
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=             2017-01-23
#
#                                               is_cancel  amount_paid_per_day
# msno
# ++L+G2jsvbkHMHlwvb2KQiRLAvB4VyEfjVJTUrs5auE=          0             4.966667
# ++XZCubnx3mWCWwaVKNyjfZjYZTysD8qvfPb/QMomeI=          1             4.966667
# ++am6f+rLDE3gjQM7pKLVAthwCgaI46WHbTNuKtgpbI=          0             4.300000
# ++k5broOoWP/P2WkW2N4C/sXL2bowW56Ep/emCCafeQ=          0             4.966667
# ++kqM73xL/v0vqbSItFKWgtEyIkW2POP4c/SEA0WZmw=          1             4.966667

# %%
transactions_features.to_pickle('tf.pkl')
